# %%
#import sys
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
image1 = cv.imread('as.jpg')
rgb_image1 = cv.cvtColor(image1, cv.COLOR_BGR2RGB)
hsv_image1 = cv.cvtColor(image1, cv.COLOR_BGR2HSV)
gray_image1 = cv.cvtColor(image1, cv.COLOR_BGR2GRAY)

channels = [0]
histSize = [256]

gs = plt.GridSpec(1,3)
plt.figure(figsize=(20, 5))
plt.subplot(gs[0])
plt.imshow(gray_image1, cmap='gray')
plt.xticks([]), plt.yticks([])
plt.subplot(gs[1])
plt.hist(gray_image1.reshape(-1), 256, [0, 255])
plt.subplot(gs[2])
plt.hist(gray_image1.reshape(-1), 256, [0, 150])
plt.show()
# Out:
# C:\Users\ulche\AppData\Local\Temp\ipykernel_15420\4062149754.py:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(gray_image1.reshape(-1), 256, [0, 255])
# C:\Users\ulche\AppData\Local\Temp\ipykernel_15420\4062149754.py:17: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(gray_image1.reshape(-1), 256, [0, 150])

# %%
threshold = 118
image = gray_image1

ret, thresh1 = cv.threshold(image, threshold, 255, cv.THRESH_BINARY)
ret, thresh2 = cv.threshold(image, threshold, 255, cv.THRESH_BINARY_INV)
ret, thresh3 = cv.threshold(image, threshold, 255, cv.THRESH_TRUNC)
titles = ['Grayscale Image', 'BINARY', 'BINARY_INV', 'TRUNC']
images = [image, thresh1, thresh2, thresh3]
plt.figure(figsize=(18, 3))
for i in np.arange(len(images)):
    plt.subplot(2, 2, i+1)
    plt.imshow(images[i], 'gray', vmin=0, vmax=255)
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
plt.imshow(cv.cvtColor(cv.imread('result.jpg'), cv.COLOR_BGR2RGB))
